
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {

        "Subject":   ["Cognitive", "ML", "CAO", "AI RIsk", "Software"],
        "Score":  [92, 100, 77, 88, 99]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Subject  Score
# 0  Cognitive     92
# 1         ML    100
# 2        CAO     77
# 3    AI RIsk     88
# 4   Software     99

# %%
sns.barplot(x="Subject", y="Score", data = df, palette="Set2")

for i in range(len(df)):
  plt.text(i, df["Score"][i]+1, df["Score"][i], ha="center")



plt.title("Subject Scores")
plt.xlabel("Subjects")
plt.ylabel("Scores")
plt.grid(axis="y")

plt.show()
# Out:
# /tmp/ipykernel_2865/2341320236.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Subject", y="Score", data = df, palette="Set2")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(1024170314)
data = np.random.seed(50)
print(data)
# Out:
# None

# %%
cum_sum = np.cumsum(data)

# %%
noise = np.random.randn(50)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.arange(50)

noise = np.random.normal(0, 1, 50)

plt.subplot(2, 2, 2)

plt.scatter(range(50), data + noise)

plt.title("Scatter Plot with Random Noise")
plt.xlabel("Index")
plt.ylabel("Value")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/AnjulaMehto/MCA/main/company_sales_data.csv"

df = pd.read_csv(url)

print(df.head())
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
sns.lineplot(x="month_number", y="total_profit", data=df, marker="o")

plt.title("Total Profit of All Months")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.grid()
plt.show()

# %%
sns.lineplot(x="month_number", y="facecream", data=df, label="Face Cream")
sns.lineplot(x="month_number", y="facewash", data=df, label="Face Wash")
sns.lineplot(x="month_number", y="toothpaste", data=df, label="Toothpaste")
sns.lineplot(x="month_number", y="bathingsoap", data=df, label="Bathing Soap")
sns.lineplot(x="month_number", y="shampoo", data=df, label="Shampoo")
sns.lineplot(x="month_number", y="moisturizer", data=df, label="Moisturizer")

plt.title("Product Sales Data")
plt.xlabel("Month Number")
plt.ylabel("Sales Units")
plt.grid()
plt.legend()
plt.show()

# %%
df.plot(x="month_number", kind="bar", figsize=(12, 6))

plt.title("Company Sales Data")
plt.xlabel("Month Number")
plt.ylabel("Values")
plt.grid(axis="y")
plt.show()

# %%
sales_columns = [
    "facecream",
    "facewash",
    "toothpaste",
    "bathingsoap",
    "shampoo",
    "moisturizer",
    "total_units",
    "total_profit"
]

for column in sales_columns:
    sns.barplot(x="month_number", y=column, data=df)
    plt.title(column)
    plt.xlabel("Month Number")
    plt.ylabel(column)
    plt.grid(axis="y")
    plt.show()
